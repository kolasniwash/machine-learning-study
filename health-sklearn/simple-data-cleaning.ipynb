# %%
import pandas as pd

# %%
sales_data = pd.read_excel('./data/sales.xlsx')
observations_data = pd.read_excel('./data/observations.xlsx')

# %% [markdown]
# #### First look at sales dataset

# %%
sales_data.tail()
# Out:
#    name_of_country  year  bikes  Unnamed: 3  Unnamed: 4 name_of_country.1  \
# 37     SWITZERLAND  1676     73         NaN         NaN       SWITZERLAND
# 38     SWITZERLAND  1677     70         NaN         NaN       SWITZERLAND
# 39     SWITZERLAND  1678     71         NaN         NaN       SWITZERLAND
# 40     SWITZERLAND  1679     66         NaN         NaN       SWITZERLAND
# 41     SWITZERLAND  1680     69         NaN         NaN       SWITZERLAND
#
#     year.1  total_turnover
# 37    1676          6380.2
# 38    1677          6118.0
# 39    1678          6205.4
# 40    1679          5768.4
# 41    1680          6030.6

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 8 columns):
# name_of_country      42 non-null object
# year                 42 non-null int64
# bikes                42 non-null int64
# Unnamed: 3           0 non-null float64
# Unnamed: 4           0 non-null float64
# name_of_country.1    42 non-null object
# year.1               42 non-null int64
# total_turnover       42 non-null float64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 2.8+ KB

# %%
sales_data.isnull().sum()
# Out:
# name_of_country       0
# year                  0
# bikes                 0
# Unnamed: 3           42
# Unnamed: 4           42
# name_of_country.1     0
# year.1                0
# total_turnover        0
# dtype: int64

# %% [markdown]
# Observations from sales dataset:
#
# - Drop the columns with no values
# - Drop columns that are duplicated

# %%
#drop unneeded columns
sales = sales_data[['name_of_country', 'year', 'bikes', 'total_turnover']]

# %%
sales.head()
# Out:
#   name_of_country  year  bikes  total_turnover
# 0         AUSTRIA  1670     60          5274.0
# 1         AUSTRIA  1671     59          5186.1
# 2         AUSTRIA  1674     53          4658.7
# 3         AUSTRIA  1675     58          5098.2
# 4         AUSTRIA  1676     56          4922.4

# %% [markdown]
# #### First look at observations dataset

# %%
observations_data.tail()
# Out:
#     countryname  year  pop
# 37  Switzerland  1676  104
# 38  Switzerland  1677   99
# 39  Switzerland  1678  101
# 40  Switzerland  1679   93
# 41  Switzerland  1680   98

# %%
observations_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 3 columns):
# countryname    42 non-null object
# year           42 non-null int64
# pop            42 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 1.1+ KB

# %%
observations_data.isnull().sum()
# Out:
# countryname    0
# year           0
# pop            0
# dtype: int64

# %% [markdown]
# Ideas from the observations dataset:
#
# - Country name and year appear to be the same values as in sales dataset.
# - Can join the observations dataset to include the pop data.

# %%
sales['pop'] = observations_data['pop']
# Out:
# /Users/ns/anaconda3/envs/fuck/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### Check the new dataset

# %%
sales
# Out:
#    name_of_country  year  bikes  total_turnover  pop
# 0          AUSTRIA  1670     60          5274.0   85
# 1          AUSTRIA  1671     59          5186.1   83
# 2          AUSTRIA  1674     53          4658.7   75
# 3          AUSTRIA  1675     58          5098.2   82
# 4          AUSTRIA  1676     56          4922.4   79
# 5          AUSTRIA  1677     50          4395.0   70
# 6          AUSTRIA  1678     57          5010.3   81
# 7          AUSTRIA  1680     57          5010.3   80
# 8           FRANCE  1673     49          4321.8   70
# 9           FRANCE  1674     56          4939.2   79
# 10          FRANCE  1675     56          4939.2   80
# 11          FRANCE  1676     53          4674.6   75
# 12          FRANCE  1677     60          5292.0   85
# 13          FRANCE  1678     55          4851.0   78
# 14          FRANCE  1680     56          4939.2   80
# 15         GERMANY  1671     49          4184.6   70
# 16         GERMANY  1672     56          4782.4   80
# ...
